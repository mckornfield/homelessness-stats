# %% [markdown]
# # 17 — City/CoC Data Collection
#
# Builds the city-level dataset from embedded CoC data with lat/lon centroids.
# This section focuses on major urban CoCs where the city-level context is most meaningful.
#
# Output: `data/processed/merged_city_data.csv`

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parent
sys.path.insert(0, str(ROOT / 'src'))

import pandas as pd
from city_data import get_merged_city_data

OUT = ROOT / 'data' / 'processed'
OUT.mkdir(parents=True, exist_ok=True)

# %%
df = get_merged_city_data()
print(f'City data: {len(df)} CoCs, {len(df.columns)} columns')
print(f'CoCs with lat/lon: {df["lat"].notna().sum()}')
# Out:
# City data: 102 CoCs, 24 columns
# CoCs with lat/lon: 102

# %%
out_path = OUT / 'merged_city_data.csv'
df.to_csv(out_path, index=False)
print(f'Saved to {out_path}')

print(f'\nTop 10 CoCs by homeless rate per 10k:')
print(df.nlargest(10, 'homeless_rate_per_10k')[['city_name', 'state_postal', 'homeless_rate_per_10k', 'unsheltered_pct', 'jan_temp_f']].to_string(index=False))
# Out:
# Saved to /Users/mckornfield/repo/homelessness-stats/data/processed/merged_city_data.csv
#
# Top 10 CoCs by homeless rate per 10k:
#     city_name state_postal  homeless_rate_per_10k  unsheltered_pct  jan_temp_f
#        Eureka           CA                 119.87             42.8          47
#        Boston           MA                 110.98              5.3          28
#    HI Balance           HI                 108.90             52.5          74
# New York City           NY                 105.59              4.3          32
# San Francisco           CA                  91.94             22.7          55
#        Denver           CO                  86.62             38.1          31
#    Sacramento           CA                  84.78             34.6          45
#      Portland           OR                  77.47             51.8          43
#          Lynn           MA                  75.50             11.0          26
#   Los Angeles           CA                  75.21             39.9          57

# %%
preview = df[['coc_code', 'city_name', 'state_postal', 'total_homeless',
              'homeless_rate_per_10k', 'unsheltered_pct', 'jan_temp_f', 'lat', 'lon']]
preview = preview.sort_values('homeless_rate_per_10k', ascending=False)
preview.head(20)
# Out:
#     coc_code      city_name state_postal  total_homeless  \
# 8     CA-522         Eureka           CA            1634
# 40    MA-500         Boston           MA            7498
# 77    HI-500     HI Balance           HI            2178
# 15    NY-600  New York City           NY           88025
# 4     CA-501  San Francisco           CA            8035
# 37    CO-503         Denver           CO            6198
# 5     CA-503     Sacramento           CA            2891
# 24    OR-501       Portland           OR            6297
# 42    MA-502           Lynn           MA             712
# 0     CA-600    Los Angeles           CA           75312
# 7     CA-511       Pasadena           CA            1038
# 55    GA-500        Atlanta           GA            3689
# 26    OR-502        Medford           OR            1463
# 20    WA-500        Seattle           WA           14190
# 101   ME-502         Bangor           ME             934
# 2     CA-500     Sacramento           CA            9278
# 3     CA-502        Oakland           CA            9747
# 19    NY-507    Schenectady           NY             912
# 11    CA-606     Long Beach           CA            2600
# 13    CA-614       San Jose           CA            9974
#
#      homeless_rate_per_10k  unsheltered_pct  jan_temp_f    lat     lon
# 8                   119.87             42.8          47  40.80 -124.16
# 40                  110.98              5.3          28  42.36  -71.06
# 77                  108.90             52.5          74  20.89 -156.47
# 15                  105.59              4.3          32  40.71  -74.01
# 4                    91.94             22.7          55  37.77 -122.42
# 37                   86.62             38.1          31  39.74 -104.98
# 5                    84.78             34.6          45  38.58 -121.49
# 24                   77.47             51.8          43  45.52 -122.68
# 42                   75.50             11.0          26  42.47  -70.95
# 0                    75.21             39.9          57  34.05 -118.24
# 7                    74.84             29.3          57  34.15 -118.14
# 55                   72.22             28.6          45  33.75  -84.39
# 26                   65.72             49.8          44  42.33 -122.87
# 20                   62.52             46.9          42  47.61 -122.33
# 101                  60.62             10.7          14  44.80  -68.78
# 2                    59.17             43.6          45  38.58 -121.49
# 3                    57.94             39.6          53  37.80 -122.27
# 19                   57.88              8.6          22  42.81  -73.94
# 11                   55.70             33.3          57  33.77 -118.19
# 13                   51.51             37.7          53  37.34 -121.89
